# %%
import numpy as np
from pylab import *
from astropy.io import fits
from scipy import stats
from astropy import units as u
import matplotlib
import matplotlib.pyplot as plt
from astropy.io import ascii
from matplotlib.ticker import FixedLocator
from astropy.stats import bayesian_blocks

# %%
import numpy as np
from astropy.io import ascii
from astropy import units
import matplotlib
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

font = {'family'         : 'serif',
	'weight'         : 'bold',
	'size'	         : 16}
matplotlib.rc('font',**font)
matplotlib.rc('grid',linewidth=1)
matplotlib.rc('xtick.major',width=2)
matplotlib.rc('xtick.major',size=7)
matplotlib.rc('xtick.minor',width=2)
matplotlib.rc('xtick.minor',size=4)
matplotlib.rc('ytick.major',width=2)
matplotlib.rc('ytick.major',size=7)
matplotlib.rc('ytick.minor',width=2)
matplotlib.rc('ytick.minor',size=4)
plt.style.use('classic')
#fig,ax=plt.subplots()
#ax.minorticks_on()
from matplotlib import gridspec
matplotlib.rc('font', family='serif', size='16',weight='bold')
matplotlib.rc('text', usetex=True)
matplotlib.rcParams['text.latex.preamble'] = [r'\boldmath']

# %%
from matplotlib import gridspec
fig = plt.figure(figsize=(9, 8)) 
gs = fig.add_gridspec(2, 1,height_ratios=[2, 1],  hspace=0.0)
ax0 = plt.subplot(gs[0])
ax1 = plt.subplot(gs[1])

data=np.loadtxt('bb_band_n0_1.qdp')
a=data[:,0]
b=data[:,1]
c=data[:,2]
d=data[:,3]
e=data[:,4]
f=data[:,5]
g=data[:,6]
ax0.errorbar(a, c, yerr = d,xerr = b, marker='o', markersize=5,color='black',ls= 'none')
ax0.plot(a,e,linestyle='-', drawstyle='steps-mid',color='black',lw=2, markersize=3)
ax0.plot(a,f,linestyle='--', color='black',lw=2,markersize=3)
ax0.plot(a,g,linestyle='--', color='black',lw=2,markersize=3)

data=np.loadtxt('bb_band_n0.qdp')
a=data[:,0]
b=data[:,1]
c=data[:,2]
d=data[:,3]
e=data[:,4]
f=data[:,5]
g=data[:,6]
ax0.errorbar(a, c, yerr = d,xerr = b, marker='o', markersize=5,color='black',ls= 'none', label=r'\textbf{NaI 0}')
ax0.legend(numpoints=1,prop={'size':12,'weight':'bold'},loc='lower left',labelspacing=0.7)
ax0.plot(a,e,linestyle='-', drawstyle='steps-mid',color='black',lw=2,markersize=3)
ax0.plot(a,f,linestyle='--', color='black',lw=2,markersize=3)
ax0.plot(a,g,linestyle='--', color='black',lw=2,markersize=3)
ax0.set_yscale('log')
ax0.set_xscale('log')
ax0.set_ylabel(r'\textbf{$\nu$} $\textbf{F}_\textbf{$\nu$}$ (\textbf{keV} $\textbf{cm}^{\textbf{-2}}$ $\textbf{s}^{\textbf{-1}}$)',fontsize='20', fontweight='bold')
ax0.xaxis.set_major_formatter(plt.NullFormatter()) 
ax0.set_xlim(8,3*10**4)
ax0.set_ylim(0.09,3e4)
ax0.minorticks_on()
ax0.tick_params(direction="in")
ax0.tick_params(axis='both',which='minor',length=3,width=1,labelsize=12)
ax0.tick_params(axis='both',which='major',length=3,width=2,labelsize=16)

data=np.loadtxt('bb_band_n1_1.qdp')
a=data[:,0]
b=data[:,1]
c=data[:,2]
d=data[:,3]
e=data[:,4]
f=data[:,5]
g=data[:,6]
ax0.errorbar(a, c, yerr = d,xerr = b, marker='o', markersize=5,color='red',ls= 'none')
ax0.plot(a,e,linestyle='-', drawstyle='steps-mid',color='red',lw=2,markersize=3)
ax0.plot(a,f,linestyle='--', color='red',lw=2,markersize=3)
ax0.plot(a,g,linestyle='--',color='red',lw=2,markersize=3)

data=np.loadtxt('bb_band_n1.qdp')
a=data[:,0]
b=data[:,1]
c=data[:,2]
d=data[:,3]
e=data[:,4]
f=data[:,5]
g=data[:,6]
ax0.errorbar(a, c, yerr = d,xerr = b, marker='o', markersize=5,color='red',ls= 'none', label=r'\textbf{NaI 1}')
ax0.legend(numpoints=1,prop={'size':12,'weight':'bold'},loc='lower left',labelspacing=0.7)
ax0.plot(a,e,linestyle='-', drawstyle='steps-mid',color='red',lw=2,markersize=3)
ax0.plot(a,f,linestyle='--', color='red',lw=2,markersize=3)
ax0.plot(a,g,linestyle='--',color='red',lw=2,markersize=3)
ax0.set_yscale('log')
ax0.set_xscale('log')
#ax0.xlabel('Energy  (keV)',fontsize='18')
#plt.ylabel('normalized counts s-1keV-1')
#ax0.set_ylabel('$\\nu$ $F_{\\nu}$ (keV $cm^{-2}$ $s^{-1}$)',fontsize='25', fontweight='bold')
ax0.xaxis.set_major_formatter(plt.NullFormatter()) 
ax0.set_xlim(8,3*10**4)

ax0.minorticks_on()
ax0.tick_params(direction="in")
ax0.tick_params(axis='both',which='minor',length=3,width=1,labelsize=12)
ax0.tick_params(axis='both',which='major',length=3,width=2,labelsize=16)

data=np.loadtxt('bb_band_n2_1.qdp')
a=data[:,0]
b=data[:,1]
c=data[:,2]
d=data[:,3]
e=data[:,4]
f=data[:,5]
g=data[:,6]
ax0.errorbar(a, c, yerr = d,xerr = b, marker='o', markersize=5,color='b',ls= 'none')
ax0.plot(a,e,linestyle='-', drawstyle='steps-mid',color='b',lw=2,markersize=3)
ax0.plot(a,f,linestyle='--', color='b',lw=2,markersize=3)
ax0.plot(a,g,linestyle='--',color='b',lw=2,markersize=3)

data=np.loadtxt('bb_band_n2.qdp')
a=data[:,0]
b=data[:,1]
c=data[:,2]
d=data[:,3]
e=data[:,4]
f=data[:,5]
g=data[:,6]
ax0.errorbar(a, c, yerr = d,xerr = b, marker='o', markersize=5,color='b',ls= 'none', label=r'\textbf{NaI 2}')
ax0.legend(numpoints=1,prop={'size':12,'weight':'bold'},loc='lower left',labelspacing=0.7)
ax0.plot(a,e,linestyle='-', drawstyle='steps-mid',color='b',lw=2,markersize=3)
ax0.plot(a,f,linestyle='--', color='b',lw=2,markersize=3)
ax0.plot(a,g,linestyle='--',color='b',lw=2,markersize=3)
ax0.set_yscale('log')
ax0.set_xscale('log')
#ax0.xlabel('Energy  (keV)',fontsize='18')
#plt.ylabel('normalized counts s-1keV-1')
#ax0.set_ylabel('$\\nu$ $F_{\\nu}$ (keV $cm^{-2}$ $s^{-1}$)',fontsize='25', fontweight='bold')
ax0.xaxis.set_major_formatter(plt.NullFormatter()) 
ax0.set_xlim(8,3*10**4)

ax0.minorticks_on()
ax0.tick_params(direction="in")
ax0.tick_params(axis='both',which='minor',length=3,width=1,labelsize=12)
ax0.tick_params(axis='both',which='major',length=3,width=2,labelsize=16)
data=np.loadtxt('bb_band_b0.qdp')
a=data[:,0]
b=data[:,1]
c=data[:,2]
d=data[:,3]
e=data[:,4]
f=data[:,5]
g=data[:,6]
ax0.errorbar(a, c, yerr = d,xerr = b, marker='o', markersize=5,color='lime',ls= 'none', label=r'\textbf{BGO 0}')
ax0.legend(numpoints=1,prop={'size':12,'weight':'bold'},loc='lower left',labelspacing=0.7)
ax0.plot(a,e,linestyle='-', drawstyle='steps-mid',color='lime',lw=2,markersize=3)
ax0.plot(a,f,linestyle='--',color='lime',lw=2,markersize=3)
ax0.plot(a,g,linestyle='--', color='lime',lw=2,markersize=3)
ax0.set_yscale('log')
ax0.set_xscale('log')
#ax0.xlabel('Energy  (keV)',fontsize='18')
#plt.ylabel('normalized counts s-1keV-1')
#ax0.set_ylabel('$\\nu$ $F_{\\nu}$ (keV $cm^{-2}$ $s^{-1}$)',fontsize='25', fontweight='bold')
ax0.xaxis.set_major_formatter(plt.NullFormatter()) 
ax0.set_xlim(8,3*10**4)

ax0.minorticks_on()
ax0.tick_params(direction="in")
ax0.tick_params(axis='both',which='minor',length=3,width=1,labelsize=12)
ax0.tick_params(axis='both',which='major',length=3,width=2,labelsize=16)



data=np.loadtxt('bb_band_n0r.qdp')
a=data[:,0]
b=data[:,1]
c=data[:,2]
d=data[:,3]
ax1.errorbar(a, c, yerr = d,xerr = b, marker='o', markersize=5,color='black',ls= 'none', label='NaI 0')
ax0.legend(numpoints=1,prop={'size':12,'weight':'bold'},loc='lower left',labelspacing=0.7)
ax1.set_xscale('log')
ax1.set_xlim(8,3*10**4)
ax1.set_xlabel(r'\textbf{Energy  (keV)}',fontsize='20', fontweight='bold')
ax1.set_ylabel(r'\textbf{Residuals}',fontsize='20', fontweight='bold')

data=np.loadtxt('bb_band_n1r.qdp')
a=data[:,0]
b=data[:,1]
c=data[:,2]
d=data[:,3]
ax1.errorbar(a, c, yerr = d,xerr = b, marker='o', markersize=5,color='red',ls= 'none', label='NaI 1')
ax0.legend(numpoints=1,prop={'size':12,'weight':'bold'},loc='lower left',labelspacing=0.7)
ax1.set_xscale('log')
ax1.set_xlim(8,3*10**4)
#ax1.set_xlabel(r'\textbf{Energy  (keV)}',fontsize='25', fontweight='bold')
#ax1.set_ylabel('Residuals',fontsize='25', fontweight='bold')
data=np.loadtxt('bb_band_n2r.qdp')
a=data[:,0]
b=data[:,1]
c=data[:,2]
d=data[:,3]
ax1.errorbar(a, c, yerr = d,xerr = b, marker='o', markersize=5,color='b',ls= 'none', label='NaI 2')
ax0.legend(numpoints=1,prop={'size':12,'weight':'bold'},loc='lower left',labelspacing=0.7)
ax1.set_xscale('log')
ax1.set_xlim(8,3*10**4)
#ax1.set_xlabel(r'\textbf{Energy  (keV)}',fontsize='25', fontweight='bold')
#ax1.set_ylabel('Residuals',fontsize='25', fontweight='bold')
ax1.set_ylim(-12,12)
ax1.yaxis.set_major_locator(FixedLocator(range(-10,10,5)))

data=np.loadtxt('bb_band_b0r.qdp')
a=data[:,0]
b=data[:,1]
c=data[:,2]
d=data[:,3]
ax1.errorbar(a, c, yerr = d,xerr = b, marker='o', markersize=5,color='lime',ls= 'none', label='BGO 0')
ax0.legend(numpoints=1,prop={'size':12,'weight':'bold'},loc='lower left',labelspacing=0.7)
ax1.set_xscale('log')
ax1.set_xlim(8,3*10**4)
ax0.text(10, 12000,'(b)',color='k',fontsize=25)

ax1.axhline(y=0.0, color='lime', linestyle='-',lw=2)
ax1.minorticks_on()
ax1.tick_params(direction="in")
ax1.tick_params(axis='both',which='minor',length=3,width=1,labelsize=12)
ax1.tick_params(axis='both',which='major',length=3,width=2,labelsize=16)
#ax1.legend.frameon=False
plt.tight_layout()

plt.savefig('bb_band_0_20sec.pdf', format='pdf')
plt.show()
